# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
movie=pd.read_csv('/Users/diwu/Desktop/Group Project/newdata2.csv')

# %%
movie
# Out:
#       Unnamed: 0                                 Title  Theaters_x  Country_x  \
# 0              0                                 Keanu        2681          1
# 1              1                                  Kedi         130          6
# 2              2                    Keep on Keepin' On           9          1
# 3              3                            Keep Quiet           3          2
# 4              4                    Keep the Lights On          10          1
# 5              5                         Keep Watching         805          1
# 6              6                      The Keeping Room          10          1
# 7              7           Keeping Up with the Joneses        3022          1
# 8              8                           Kelly & Cal           6          1
# 9              9          Kevin Hart: Laugh at My Pain         287          1
# 10            10            Kevin Hart: Let Me Explain         892          1
# ...

# %%
del movie["Unnamed: 0"]

# %%
movieruntime=movie2[movie2['googletrends'] != 0]

# %%
plt.scatter(movie2["count_num"],movie2["Total Gross_x"])
plt.show()

# %%
movie2['Genre_x']=movie2['Genre_x'].astype(int)
# Out:
# /Users/diwu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.savefig('Theaters_Gross.png')
# share x only

# %%
plt.figure()
movie2.groupby('Genre_x').count()['Total Gross_x'].plot.bar()
plt.savefig('Genre2')

# %%
movie2
# Out:
# 3764

# %%
movie2.groupby('Genre_x').mean()['Total Gross_x'].plot.bar()
plt.show()
